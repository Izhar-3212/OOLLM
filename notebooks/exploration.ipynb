# %%
from pathlib import Path

project_root = Path.cwd()
print('Project root:', project_root)
print('Notebook ready for experimentation.')

# %% [markdown]
# # TinyLlama Chatbot Project
#
# This notebook is a starter workspace for exploring data preparation, fine-tuning, and inference steps for the TinyLlama chatbot project.
